# %% [markdown]
# **Decision Tree** -> It is a binary tree with conditions and decisions . for every input it recursively find the decisions and gives out the best output

# %% [markdown]
# importing necessary packages for building the model

# %% [markdown]
# pandas - For data handling purpose

# %%
import pandas as pd

# %% [markdown]
# numpy - for mathematical operations and array based computation since model could only handle numerical values in array

# %%
import numpy as np

# %% [markdown]
# train_test_split - We need to split the dataset in 80% training 20% testing to test our model and also check if it is underfitting or overfitting

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# LabelEncoder - we have to convert the text data to numerical data because model could only handle numerical data

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Decision Tree - To build our Decision Tree model

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Model Evaluation - To evaluate the performance of our model using accuracy score and confusion matrix and classification report

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# Tree Visualization - Visualization of the decision tree using matplotlib and plot tree

# %%
from sklearn.tree import plot_tree 
import matplotlib.pyplot as plt

# %% [markdown]
# Seaborn - For more visualization purposes

# %%
import seaborn as sns

# %% [markdown]
# Let's load our dataset to start our training

# %%
data = pd.read_csv("dataset/loan_data.csv")

# %%
data
# Out:
#      Gender Married     Education Self_Employed  ApplicantIncome  \
# 0    Female     Yes  Not Graduate            No             6841
# 1      Male     Yes  Not Graduate            No             4017
# 2      Male     Yes  Not Graduate           Yes             8665
# 3    Female      No      Graduate            No             3452
# 4    Female      No      Graduate           Yes             6673
# ..      ...     ...           ...           ...              ...
# 245    Male     Yes      Graduate           Yes             3971
# 246  Female     Yes  Not Graduate           Yes             4369
# 247  Female      No      Graduate            No             8234
# 248  Female      No  Not Graduate            No             5840
# 249    Male      No      Graduate           Yes             5484
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                 1126         107               240               1
# ...

# %% [markdown]
# Now we have to split our dataset primarily to input features and target
#
# Input Features (X) -> all the factors such as gender,education,income etc
#
# Target (Y) -> loan status whether approved or rejected

# %% [markdown]
# Let's set the Input Feature (X) values

# %%
X= data.drop("Loan_Status",axis=1) #add everything other than loan status

# %% [markdown]
# Setting the Target (Y)

# %%
y=data["Loan_Status"]

# %% [markdown]
# Since models can't interpret text dataset, we are gonna convert them into numeric values with the help of label encoders
#
# eg: approved :0 rejected :0
#     rural :0 semi-urban :1 urban :2

# %%
encoder = LabelEncoder()

# %% [markdown]
# Encoding the x values

# %%
for column in X.columns:
    if X[column] = encoder.fit_transform(X[column])

# %% [markdown]
# Encoding Target Y values

# %%
y=encoder.fit_transform(y)
